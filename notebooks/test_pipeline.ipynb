# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import os

from franklab_mountainsort import (get_mda_files_dataframe, move_mda_data,
                                   spike_sort_all)

import logging

FORMAT = '%(asctime)s %(message)s'

logging.basicConfig(level='INFO', format=FORMAT, datefmt='%d-%b-%y %H:%M:%S')

# %%
animal = 'kf19'
dates = ['20170913']
target_path = '/opt/vortex2/edeno'

source_animal_path = f'/data2/jason/{animal}/preprocessing'

input_path = os.path.join(target_path, animal, 'preprocessing')
output_path = os.path.join(target_path, animal, 'mountainlab_output')
temp_path = os.path.join(target_path, 'temp2')
log_directory = os.path.join(target_path, 'temp2')

os.environ['ML_TEMPORARY_DIRECTORY'] = temp_path

# %%
logging.info(f'original data directory: {source_animal_path}')
logging.info(f'copied data directory: {input_path}')
logging.info(f'output directory: {output_path}')
logging.info(f'temp directory: {temp_path}')
logging.info(f'log directory: {log_directory}')
# Out:
# 17-Sep-19 09:12:41 original data directory: /data2/jason/kf19/preprocessing
# 17-Sep-19 09:12:41 copied data directory: /opt/vortex2/edeno/kf19/preprocessing
# 17-Sep-19 09:12:41 output directory: /opt/vortex2/edeno/kf19/mountainlab_output
# 17-Sep-19 09:12:41 temp directory: /opt/vortex2/edeno/temp2
# 17-Sep-19 09:12:41 log directory: /opt/vortex2/edeno/temp2

# %%
move_mda_data(
    source_animal_path, input_path, animal, dates)

# %%
mda_file_info = get_mda_files_dataframe('/opt/vortex2/edeno/kf19/preprocessing')
mda_file_info.query('epoch == 2')
# Out:
# 17-Sep-19 09:12:41 Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 17-Sep-19 09:12:41 NumExpr defaulting to 8 threads.
#                                        task  \
# animal date     epoch electrode_number
# kf19   20170913 2     1                  r1
#                       2                  r1
#                       3                  r1
#                       4                  r1
#                       5                  r1
#                       6                  r1
#                       7                  r1
#                       8                  r1
#                       9                  r1
#                       10                 r1
#                       11                 r1
#                       12                 r1
#                       13                 r1
#                       14                 r1
#                       15                 r1
#                       16                 r1
# ...

# %%
spike_sort_all(
    mda_file_info.query('epoch == 2'), input_path, output_path,
    metrics_input='metrics_merged.json',
    metrics_output='metrics_merged_tagged.json',
    firing_rate_thresh=0.01, isolation_thresh=0.95,
    noise_overlap_thresh=0.03, peak_snr_thresh=3,
    extract_marks=False, freq_min=600)
# Out:
# 17-Sep-19 09:12:41 Processing animal: kf19, date: 20170913, electrode: 1
# ...
